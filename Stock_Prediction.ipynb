# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6

# %%
display (os.getcwd())
# Out:
# '/content'

# %%
df =pd.read_csv("prices.csv", header=0)
display (df)
# Out:
#                        date symbol        open       close         low  \
# 0       2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998
# 1       2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002
# 2       2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000
# 3       2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000
# 4       2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996
# ...                     ...    ...         ...         ...         ...
# 851259           2016-12-30    ZBH  103.309998  103.199997  102.849998
# 851260           2016-12-30   ZION   43.070000   43.040001   42.689999
# 851261           2016-12-30    ZTS   53.639999   53.529999   53.270000
# 851262  2016-12-30 00:00:00    AIV   44.730000   45.450001   44.410000
# 851263  2016-12-30 00:00:00    FTV   54.200001   53.630001   53.389999
#
#               high     volume
# 0       126.250000  2163600.0
# 1       125.540001  2386400.0
# 2       119.739998  2489500.0
# 3       117.440002  2006300.0
# 4       117.330002  1408600.0
# ...            ...        ...
# 851259  103.930000   973800.0
# 851260   43.310001  1938100.0
# 851261   53.740002  1701200.0
# 851262   45.590000  1380900.0
# 851263   54.480000   705100.0
#
# [851264 rows x 7 columns]

# %%
#Display the shape
print(df.shape)

#Display the column names
print(df.columns)

#Value count (Number of records by company)
print (df.symbol.value_counts())

#Unique Values
print (df.symbol.unique())

#Number of Unique Values
display(df.symbol.unique().shape)

#First 20 Unique values
print (df.symbol.unique()[0:20])


#Number of Records
print(len(df.symbol.values))

#Display Info
df.info()

#Describe the column
# Gives the details of each column of the dataset like mean, max, etc
display (df.describe())

#Check for NULL Values
#checking whether there is any null value in the dataset
# .sum() will give the total no. of null value column-wise

#display (df.isnull().sum())

#Get all Unique Dates
display (df.date.unique())

#Display Date as  Data Frame
display (pd.DataFrame(df.date.unique()))

#Check for Duplicate Records
display (df.duplicated().sum())
# Out:
# (851264, 7)
# Index(['date', 'symbol', 'open', 'close', 'low', 'high', 'volume'], dtype='object')
# symbol
# AIV     1762
# ZION    1762
# ZBH     1762
# YUM     1762
# AMGN    1762
#         ...
# KHC      378
# HPE      304
# CSRA     284
# WLTW     251
# FTV      126
# Name: count, Length: 501, dtype: int64
# ['WLTW' 'A' 'AAL' 'AAP' 'AAPL' 'ABC' 'ABT' 'ACN' 'ADBE' 'ADI' 'ADM' 'ADP'
#  'ADS' 'ADSK' 'AEE' 'AEP' 'AES' 'AET' 'AFL' 'AGN' 'AIG' 'AIZ' 'AJG' 'AKAM'
#  'ALB' 'ALK' 'ALL' 'ALXN' 'AMAT' 'AME' 'AMG' 'AMGN' 'AMP' 'AMT' 'AMZN'
#  'AN' 'ANTM' 'AON' 'APA' 'APC' 'APD' 'APH' 'ARNC' 'ATVI' 'AVB' 'AVGO'
#  'AVY' 'AWK' 'AXP' 'AYI' 'AZO' 'BA' 'BAC' 'BAX' 'BBBY' 'BBT' 'BBY' 'BCR'
#  'BDX' 'BEN' 'BHI' 'BIIB' 'BK' 'BLK' 'BLL' 'BMY' 'BSX' 'BWA' 'BXP' 'C'
#  'CA' 'CAG' 'CAH' 'CAT' 'CB' 'CBG' 'CBS' 'CCI' 'CCL' 'CELG' 'CERN' 'CF'
#  'CHD' 'CHK' 'CHRW' 'CI' 'CINF' 'CL' 'CLX' 'CMA' 'CMCSA' 'CME' 'CMG' 'CMI'
#  'CMS' 'CNC' 'CNP' 'COF' 'COG' 'COH' 'COL' 'COO' 'COP' 'COST' 'CPB' 'CRM'
#  'CSCO' 'CSX' 'CTAS' 'CTL' 'CTSH' 'CTXS' 'CVS' 'CVX' 'CXO' 'D' 'DAL' 'DD'
#  'DE' 'DFS' 'DG' 'DGX' 'DHI' 'DHR' 'DIS' 'DISCA' 'DISCK' 'DLR' 'DLTR'
#  'DNB' 'DOV' 'DOW' 'DPS' 'DRI' 'DTE' 'DUK' 'DVA' 'DVN' 'EA' 'EBAY' 'ECL'
#  'ED' 'EFX' 'EIX' 'EL' 'EMN' 'EMR' 'ENDP' 'EOG' 'EQIX' 'EQR' 'EQT' 'ES'
#  'ESRX' 'ESS' 'ETFC' 'ETN' 'ETR' 'EW' 'EXC' 'EXPD' 'EXPE' 'EXR' 'F' 'FAST'
#  'FCX' 'FDX' 'FE' 'FFIV' 'FIS' 'FISV' 'FITB' 'FL' 'FLIR' 'FLR' 'FLS' 'FMC'
#  'FOX' 'FOXA' 'FRT' 'FSLR' 'FTI' 'FTR' 'GD' 'GE' 'GGP' 'GILD' 'GIS' 'GLW'
#  'GOOG' 'GOOGL' 'GPC' 'GPN' 'GPS' 'GRMN' 'GS' 'GT' 'GWW' 'HAL' 'HAR' 'HAS'
#  'HBAN' 'HBI' 'HCN' 'HCP' 'HD' 'HES' 'HIG' 'HOG' 'HOLX' 'HON' 'HP' 'HPQ'
#  'HRB' 'HRL' 'HRS' 'HSIC' 'HST' 'HSY' 'HUM' 'IBM' 'ICE' 'IDXX' 'IFF'
#  'ILMN' 'INTC' 'INTU' 'IP' 'IPG' 'IR' 'IRM' 'ISRG' 'ITW' 'IVZ' 'JBHT'
#  'JCI' 'JEC' 'JNJ' 'JNPR' 'JPM' 'JWN' 'K' 'KEY' 'KIM' 'KLAC' 'KMB' 'KMX'
#  'KO' 'KR' 'KSS' 'KSU' 'L' 'LB' 'LEG' 'LEN' 'LH' 'LKQ' 'LLL' 'LLTC' 'LLY'
#  'LMT' 'LNC' 'LNT' 'LOW' 'LRCX' 'LUK' 'LUV' 'LVLT' 'M' 'MA' 'MAA' 'MAC'
#  'MAR' 'MAS' 'MAT' 'MCD' 'MCHP' 'MCK' 'MCO' 'MDLZ' 'MDT' 'MET' 'MHK' 'MJN'
#  'MKC' 'MLM' 'MMC' 'MMM' 'MNST' 'MO' 'MON' 'MOS' 'MRK' 'MRO' 'MSFT' 'MSI'
#  'MTB' 'MTD' 'MU' 'MUR' 'MYL' 'NBL' 'NDAQ' 'NEE' 'NEM' 'NFLX' 'NFX' 'NI'
#  'NKE' 'NOC' 'NOV' 'NRG' 'NSC' 'NTAP' 'NTRS' 'NUE' 'NVDA' 'NWL' 'O' 'OKE'
#  'OMC' 'ORCL' 'ORLY' 'OXY' 'PAYX' 'PBCT' 'PBI' 'PCAR' 'PCG' 'PCLN' 'PDCO'
#  'PEG' 'PEP' 'PFE' 'PFG' 'PG' 'PGR' 'PH' 'PHM' 'PKI' 'PLD' 'PM' 'PNC'
#  'PNR' 'PNW' 'PPG' 'PPL' 'PRGO' 'PRU' 'PSA' 'PVH' 'PWR' 'PX' 'PXD' 'QCOM'
#  'R' 'RAI' 'RCL' 'REGN' 'RF' 'RHI' 'RHT' 'RIG' 'RL' 'ROK' 'ROP' 'ROST'
#  'RRC' 'RSG' 'RTN' 'SBUX' 'SCG' 'SCHW' 'SE' 'SEE' 'SHW' 'SIG' 'SJM' 'SLB'
#  'SLG' 'SNA' 'SNI' 'SO' 'SPG' 'SPGI' 'SPLS' 'SRCL' 'SRE' 'STI' 'STT' 'STX'
#  'STZ' 'SWK' 'SWKS' 'SWN' 'SYK' 'SYMC' 'SYY' 'T' 'TAP' 'TDC' 'TEL' 'TGNA'
#  'TGT' 'TIF' 'TJX' 'TMK' 'TMO' 'TROW' 'TRV' 'TSCO' 'TSN' 'TSO' 'TSS' 'TWX'
#  'TXN' 'TXT' 'UAA' 'UAL' 'UDR' 'UHS' 'ULTA' 'UNH' 'UNM' 'UNP' 'UPS' 'URBN'
#  'URI' 'USB' 'UTX' 'V' 'VAR' 'VFC' 'VIAB' 'VLO' 'VMC' 'VNO' 'VRSK' 'VRSN'
#  'VRTX' 'VTR' 'VZ' 'WAT' 'WBA' 'WDC' 'WEC' 'WFC' 'WFM' 'WHR' 'WM' 'WMB'
#  'WMT' 'WU' 'WY' 'WYN' 'WYNN' 'XEC' 'XEL' 'XL' 'XLNX' 'XOM' 'XRAY' 'XRX'
#  'YHOO' 'YUM' 'ZBH' 'ZION' 'AIV' 'CHTR' 'LYB' 'GM' 'ABBV' 'DLPH' 'FB'
#  'FBHS' 'HCA' 'KMI' 'KORS' 'MPC' 'NLSN' 'PSX' 'TDG' 'TRIP' 'XYL' 'ZTS'
#  'COTY' 'MNK' 'NWS' 'NWSA' 'EVHC' 'ALLE' 'CFG' 'NAVI' 'QRVO' 'SYF' 'WRK'
#  'KHC' 'PYPL' 'HPE' 'CSRA' 'FTV']
# (501,)
# ['WLTW' 'A' 'AAL' 'AAP' 'AAPL' 'ABC' 'ABT' 'ACN' 'ADBE' 'ADI' 'ADM' 'ADP'
#  'ADS' 'ADSK' 'AEE' 'AEP' 'AES' 'AET' 'AFL' 'AGN']
# 851264
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 851264 entries, 0 to 851263
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    851264 non-null  object
#  1   symbol  851264 non-null  object
#  2   open    851264 non-null  float64
#  3   close   851264 non-null  float64
#  4   low     851264 non-null  float64
#  5   high    851264 non-null  float64
#  6   volume  851264 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 45.5+ MB
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       70.836986      70.857109      70.118414      71.543476
# std        83.695876      83.689686      82.877294      84.465504
# min         0.850000       0.860000       0.830000       0.880000
# 25%        33.840000      33.849998      33.480000      34.189999
# 50%        52.770000      52.799999      52.230000      53.310001
# 75%        79.879997      79.889999      79.110001      80.610001
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08
# array(['2016-01-05 00:00:00', '2016-01-06 00:00:00',
#        '2016-01-07 00:00:00', ..., '2016-12-28', '2016-12-29',
#        '2016-12-30'], dtype=object)
#                         0
# 0     2016-01-05 00:00:00
# 1     2016-01-06 00:00:00
# 2     2016-01-07 00:00:00
# 3     2016-01-08 00:00:00
# 4     2016-01-11 00:00:00
# ...                   ...
# 3519           2016-12-23
# 3520           2016-12-27
# 3521           2016-12-28
# 3522           2016-12-29
# 3523           2016-12-30
#
# [3524 rows x 1 columns]
# np.int64(0)

# %%
comp_info = pd.read_csv('securities.csv')
display (comp_info)

#Check for Unique count
print (comp_info["Ticker symbol"].nunique())

#Check for info
comp_info.info()

#Check for Null Values
print (comp_info.isnull().sum())

#Describe the Details
print (comp_info.describe())

#Search for Particular company details
# for locating specific data here.... in security column of string that starts with "Face"
display(comp_info.loc[comp_info.Security.str.startswith('Face') , :])
# Out:
#     Ticker symbol                Security SEC filings             GICS Sector  \
# 0             MMM              3M Company     reports             Industrials
# 1             ABT     Abbott Laboratories     reports             Health Care
# 2            ABBV                  AbbVie     reports             Health Care
# 3             ACN           Accenture plc     reports  Information Technology
# 4            ATVI     Activision Blizzard     reports  Information Technology
# ..            ...                     ...         ...                     ...
# 500          YHOO              Yahoo Inc.     reports  Information Technology
# 501           YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 502           ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503          ZION           Zions Bancorp     reports              Financials
# 504           ZTS                  Zoetis     reports             Health Care
#
#                   GICS Sub Industry   Address of Headquarters  \
# 0          Industrial Conglomerates       St. Paul, Minnesota
# 1             Health Care Equipment   North Chicago, Illinois
# 2                   Pharmaceuticals   North Chicago, Illinois
# 3    IT Consulting & Other Services           Dublin, Ireland
# 4       Home Entertainment Software  Santa Monica, California
# ..                              ...                       ...
# 500    Internet Software & Services     Sunnyvale, California
# 501                     Restaurants      Louisville, Kentucky
# 502           Health Care Equipment           Warsaw, Indiana
# 503                  Regional Banks      Salt Lake City, Utah
# 504                 Pharmaceuticals  Florham Park, New Jersey
#
#     Date first added      CIK
# 0                NaN    66740
# 1         31-03-1964     1800
# 2         31-12-2012  1551152
# 3         06-07-2011  1467373
# 4         31-08-2015   718877
# ..               ...      ...
# 500              NaN  1011006
# 501       06-10-1997  1041061
# 502              NaN  1136869
# 503              NaN   109380
# 504       21-06-2013  1555280
#
# [505 rows x 8 columns]
# 505
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Ticker symbol            505 non-null    object
#  1   Security                 505 non-null    object
#  2   SEC filings              505 non-null    object
#  3   GICS Sector              505 non-null    object
#  4   GICS Sub Industry        505 non-null    object
#  5   Address of Headquarters  505 non-null    object
#  6   Date first added         307 non-null    object
#  7   CIK                      505 non-null    int64
# dtypes: int64(1), object(7)
# memory usage: 31.7+ KB
# Ticker symbol                0
# Security                     0
# SEC filings                  0
# GICS Sector                  0
# GICS Sub Industry            0
# Address of Headquarters      0
# Date first added           198
# CIK                          0
# dtype: int64
#                 CIK
# count  5.050000e+02
# mean   7.074490e+05
# std    5.144375e+05
# min    1.800000e+03
# 25%    8.631200e+04
# 50%    8.310010e+05
# 75%    1.075531e+06
# max    1.659166e+06
#     Ticker symbol  Security SEC filings             GICS Sector  \
# 181            FB  Facebook     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 181  Internet Software & Services  Menlo Park, California       23-12-2013
#
#          CIK
# 181  1326801

# %%
#For Loop to display 6 Company names
for i in comp_plot:
    print (i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-500815571.py in <cell line: 0>()
#       1 #For Loop to display 6 Company names
# ----> 2 for i in comp_plot:
#       3     print (i)
#
# NameError: name 'comp_plot' is not defined

# %%
# here we locate Ticker symbol of company with security like Yahoo, Xerox, Adobe etc, then taking their no. of times entry and thier "Ticker symbol"
#In the result, left side 6.181,212 etc the index values corresponds to the selected companies from  comp info

comp_plot = comp_info.loc[(comp_info["Security"] == 'Yahoo Inc.') | (comp_info["Security"] == 'Xerox Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Microsoft Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Facebook') | (comp_info["Security"] == 'Goldman Sachs Group') , ["Ticker symbol"] ]["Ticker symbol"]
print(comp_plot)

#For Loop to display 6 Company names
for i in comp_plot:
    print (i)
# Out:
# 6      ADBE
# 181      FB
# 212      GS
# 306    MSFT
# 496     XRX
# 500    YHOO
# Name: Ticker symbol, dtype: object
# ADBE
# FB
# GS
# MSFT
# XRX
# YHOO

# %%
#Create a function to plot Graphs for selected companies  opening stock and closing stock against time
def plotter(code):
    # Function used to create graphs for 6 companies
    global closing_stock ,opening_stock
    #creating plot of all 6 company for opening and closing stock  total 12 graphs
    # Below statement create 2X2 empty chart
    f, axs = plt.subplots(2,2,figsize=(15,8))
    # total 12 graphs
    # creating plot opening prize of particular company
    plt.subplot(212)
    #taking name of the company as code, get all records related to one company
    company = df[df['symbol']==code]
    #taking the values of one company and taking its open column values to 1D array
    company = company.open.values.astype('float32')
    #reshaping the open stock value from 1D  to 2D .
    company = company.reshape(-1, 1)
# putting the value of company in opening_stock
    opening_stock = company
    # plotting the data with green graph between "Time" and "prices vs time"

    plt.grid(True)#enalbling the grid in graph
    plt.xlabel('Time') # setting X axis as time
    # setting Y axis as company name + open stock prices
    plt.ylabel(code + " open stock prices")
    plt.title('prices Vs Time') # setting title
    plt.plot(company , 'g') # calling the graph with green graph line

    # creating plot closing prize of particular company
    plt.subplot(211)
    #taking name of the company as code
    company_close = df[df['symbol']==code]
    #taking the values of one company and taking its close column values
    company_close = company_close.close.values.astype('float32')
    #reshaping the open column value in 1D and calling it closing_stock

    # -1 for unknown dimension
    company_close = company_close.reshape(-1, 1)
    # putting company_close value in closing_stock
    closing_stock = company_close
    # plotting the data graph between "Time" and "prices vs time"
    plt.xlabel('Time') # setting x axis as time
    plt.ylabel(code + " close stock prices")# setting y axis as company name + open stock prices
    plt.title('prices Vs Time') # setting title as price vs time
    plt.grid(True) # enabling the grid in graph
    plt.plot(company_close , 'b') #creating the data graph in blue graph line
    plt.show() # calling the graph

    #Calling the graphs through the function
for i in comp_plot:
    plotter(i)

# %%
#Extract closing stock of one company, here YHOO
stocks= np.array (df[df.symbol.isin (['YHOO'])].close)
print(stocks)
display (stocks.shape)
#Convert stock to 2D array
stocks = stocks.reshape(len(stocks) , 1)
print (stocks.shape)
print(stocks)
# Out:
# [17.1      17.23     17.17     ... 38.73     38.639999 38.669998]
# (1762,)
# (1762, 1)
# [[17.1     ]
#  [17.23    ]
#  [17.17    ]
#  ...
#  [38.73    ]
#  [38.639999]
#  [38.669998]]

# %%
#Min Max Scaler
#Feature scaling the vector for better model performance.
from sklearn.preprocessing import MinMaxScaler
#scaling features between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
stocks = scaler.fit_transform(stocks)
display (stocks)
# Out:
# array([[0.14559109],
#        [0.14874031],
#        [0.14728683],
#        ...,
#        [0.66957366],
#        [0.6673934 ],
#        [0.66812012]])

# %%
#Train Test Split (80 % Training and 20 % Test Data)
#Total Number of Records
print (stocks.shape)

# 80 % Training record count
train = int(len(stocks) * 0.80)
print (train)

# 20 % record count    (Total – 80%)
test = len(stocks) - train
print (test)
# Out:
# (1762, 1)
# 1409
# 353

# %%
#Training Data
#divinding the values of stocks data to train from 0 to 1409 i.e 80% data
train = stocks[0:train]
display (train.shape)
print(train)

#Test Data
#divinding the values of stocks data to test from train ending to stock data ending i.e rest 20% data
test = stocks[len(train) : ]
display(test.shape)
display (test)
# Out:
# (1409, 1)
# [[0.14559109]
#  [0.14874031]
#  [0.14728683]
#  ...
#  [0.63372095]
#  [0.61458332]
#  [0.61967051]]
# (353, 1)
# array([[0.63129851],
#        [0.60416666],
#        [0.56686053],
#        [0.6017442 ],
#        [0.60925394],
#        [0.60586237],
#        [0.59593022],
#        [0.58381782],
#        [0.55741276],
#        [0.52906978],
#        [0.48982557],
#        [0.50024226],
#        [0.51913761],
#        [0.54748061],
#        [0.53415697],
#        [0.51235471],
#        [0.49685079],
#        [0.500969  ],
#        [0.51962213],
#        [0.49636629],
#        [0.47989342],
#        [0.4949128 ],
#        [0.48594962],
#        [0.49273257],
#        [0.46584303],
#        [0.48328492],
#        [0.49200583],
#        [0.48062017],
#        [0.47601745],
#        [0.48643412],
#        [0.46778102],
#        [0.45179265],
#        [0.44210272],
#        [0.43701549],
#        [0.39995156],
#        [0.41593993],
#        [0.43168606],
#        [0.43168606],
#        [0.47529068],
#        [0.47868218],
#        [0.48134689],
#        [0.50339151],
#        [0.51550386],
#        [0.51913761],
#        [0.52737407],
#        [0.51477714],
#        [0.50872094],
#        [0.54239342],
#        [0.53972867],
#        [0.54287792],
#        [0.52664735],
#        [0.4852229 ],
#        [0.49854652],
#        [0.53488369],
#        [0.54045549],
#        [0.56225774],
#        [0.58381782],
#        [0.58042635],
#        [0.59423449],
#        [0.58575583],
#        [0.57243221],
#        [0.58091087],
#        [0.58212208],
#        [0.55983531],
#        [0.54723839],
#        [0.55474812],
#        [0.53997097],
#        [0.53633722],
#        [0.5111434 ],
#        [0.5295543 ],
#        [0.52737407],
#        [0.53028102],
#        [0.52180236],
#        [0.53343027],
#        [0.53948647],
#        [0.5297965 ],
#        [0.53464149],
#        [0.529312  ],
#        [0.55038763],
#        [0.54796511],
#        [0.5949613 ],
#        [0.56322676],
#        [0.5770349 ],
#        [0.57146319],
#        [0.57558136],
#        [0.56468029],
#        [0.57025198],
#        [0.52858528],
#        [0.52083335],
#        [0.53149224],
#        [0.54966084],
#        [0.53633722],
#        [0.5295543 ],
#        [0.5300388 ],
#        [0.55959301],
#        [0.56589151],
#        [0.55765508],
#        [0.54530035],
#        [0.55595934],
#        [0.53972867],
#        [0.53706392],
#        [0.49200583],
#        [0.5113857 ],
#        [0.51041668],
#        [0.46196707],
#        [0.4733527 ],
#        [0.46220931],
#        [0.47480624],
#        [0.44452523],
#        [0.46584303],
#        [0.43725774],
#        [0.45179265],
#        [0.42853686],
#        [0.44137596],
#        [0.45203489],
#        [0.45276166],
#        [0.4576066 ],
#        [0.45058143],
#        [0.42781009],
#        [0.44622094],
#        [0.44767443],
#        [0.43531975],
#        [0.40188954],
#        [0.43750001],
#        [0.40891471],
#        [0.38662789],
#        [0.38105621],
#        [0.38783916],
#        [0.37960272],
#        [0.38638569],
#        [0.44064926],
#        [0.44282949],
#        [0.44404071],
#        [0.45906011],
#        [0.48643412],
#        [0.47432172],
#        [0.48110469],
#        [0.49103686],
#        [0.49127911],
#        [0.50145352],
#        [0.52592053],
#        [0.52858528],
#        [0.52785856],
#        [0.55159887],
#        [0.55402131],
#        [0.52906978],
#        [0.54312012],
#        [0.52640505],
#        [0.55038763],
#        [0.54481595],
#        [0.53706392],
#        [0.55523252],
#        [0.56177325],
#        [0.5833333 ],
#        [0.59060081],
#        [0.5891473 ],
#        [0.57437014],
#        [0.57582368],
#        [0.58478684],
#        [0.61119188],
#        [0.61700585],
#        [0.62306205],
#        [0.61506784],
#        [0.62814924],
#        [0.61337211],
#        [0.61942831],
#        [0.60755811],
#        [0.60513567],
#        [0.61506784],
#        [0.61942831],
#        [0.63517446],
#        [0.63178291],
#        [0.61579454],
#        [0.61603684],
#        [0.61143417],
#        [0.64801358],
#        [0.64389532],
#        [0.63929265],
#        [0.63323645],
#        [0.6303295 ],
#        [0.62645353],
#        [0.61773257],
#        [0.61797477],
#        [0.61627906],
#        [0.60368214],
#        [0.60343994],
#        [0.62621123],
#        [0.63323645],
#        [0.63202521],
#        [0.63832363],
#        [0.6366279 ],
#        [0.62839146],
#        [0.61506784],
#        [0.63929265],
#        [0.63420544],
#        [0.63347875],
#        [0.62814924],
#        [0.61555234],
#        [0.61942831],
#        [0.64050387],
#        [0.59350777],
#        [0.62185074],
#        [0.64752909],
#        [0.65043604],
#        [0.61918611],
#        [0.63129851],
#        [0.61797477],
#        [0.62936048],
#        [0.62112405],
#        [0.62693802],
#        [0.63614338],
#        [0.62354658],
#        [0.61482562],
#        [0.63735472],
#        [0.63541668],
#        [0.63711239],
#        [0.62621123],
#        [0.63468996],
#        [0.63735472],
#        [0.6363857 ],
#        [0.64656007],
#        [0.60925394],
#        [0.58454461],
#        [0.60440895],
#        [0.6242733 ],
#        [0.64123066],
#        [0.65164735],
#        [0.63977715],
#        [0.64001935],
#        [0.64026164],
#        [0.64559115],
#        [0.65092053],
#        [0.6492248 ],
#        [0.6431686 ],
#        [0.65092053],
#        [0.64510663],
#        [0.65067833],
#        [0.65600772],
#        [0.67369193],
#        [0.67248059],
#        [0.68531981],
#        [0.65964149],
#        [0.67030036],
#        [0.66787792],
#        [0.66448645],
#        [0.65649224],
#        [0.67126937],
#        [0.66569769],
#        [0.6613372 ],
#        [0.67417632],
#        [0.67587216],
#        [0.68192836],
#        [0.68192836],
#        [0.69864343],
#        [0.73110467],
#        [0.77156007],
#        [0.76501935],
#        [0.76065898],
#        [0.76574617],
#        [0.77059115],
#        [0.77349808],
#        [0.76138568],
#        [0.76332361],
#        [0.74660855],
#        [0.7495155 ],
#        [0.75532948],
#        [0.75508718],
#        [0.76283921],
#        [0.76695738],
#        [0.77131785],
#        [0.77979651],
#        [0.81443798],
#        [0.80571703],
#        [0.80595935],
#        [0.77107555],
#        [0.78415697],
#        [0.7739826 ],
#        [0.78415697],
#        [0.79699619],
#        [0.78924416],
#        [0.77761627],
#        [0.7679264 ],
#        [0.80062984],
#        [0.80087216],
#        [0.7681686 ],
#        [0.755814  ],
#        [0.78197674],
#        [0.78972868],
#        [0.76259692],
#        [0.77543602],
#        [0.77616283],
#        [0.77737405],
#        [0.79021317],
#        [0.78948645],
#        [0.77834307],
#        [0.79530036],
#        [0.76526165],
#        [0.75750973],
#        [0.73958333],
#        [0.73522286],
#        [0.74370159],
#        [0.74103684],
#        [0.76647289],
#        [0.75799423],
#        [0.75290695],
#        [0.76308141],
#        [0.7621124 ],
#        [0.75072681],
#        [0.74563953],
#        [0.7434593 ],
#        [0.73788759],
#        [0.73255821],
#        [0.71681203],
#        [0.70591087],
#        [0.70712209],
#        [0.72577519],
#        [0.72843994],
#        [0.72965116],
#        [0.70421513],
#        [0.71051353],
#        [0.68338178],
#        [0.70542635],
#        [0.72407947],
#        [0.73546516],
#        [0.72916666],
#        [0.72722872],
#        [0.72480617],
#        [0.72359495],
#        [0.72141472],
#        [0.73546516],
#        [0.73909881],
#        [0.72504847],
#        [0.69137601],
#        [0.7020349 ],
#        [0.70518415],
#        [0.69961244],
#        [0.71293606],
#        [0.73449614],
#        [0.74297478],
#        [0.73183139],
#        [0.73594965],
#        [0.72238374],
#        [0.66182172],
#        [0.66666671],
#        [0.66206392],
#        [0.67999033],
#        [0.67974813],
#        [0.66400195],
#        [0.66787792],
#        [0.67417632],
#        [0.66957366],
#        [0.6673934 ],
#        [0.66812012]])

# %%
#Function to prepare the data, use two previous values to predict for third data
#creating function to create trainX,testX and target(trainY, testY)
def process_data(data , n_features):
    dataX, dataY = [], [] # creating data for dataset and dividing inta X,Y
    for i in range(len(data)-n_features):
        # taking i range from total size- 3
        a = data[i:(i+n_features), 0]
        # Here a is value of data from i to i+ n_features, ie two values and put it in dataX
        dataX.append(a) #putting a in dataX
        #here dataY takes the value of data of i + n_features
        dataY.append(data[i + n_features, 0])
        # putting i+ n_features in  dataY
    return np.array(dataX), np.array(dataY)
# returning dataX and dataY in array

# %%
#Call the function to prepare training data
n_features = 2
# Here we create train X, Train Y and test X, Test Y data where trainX, testX has two value is each block
trainX, trainY = process_data(train, n_features)
print(trainX.shape , trainY.shape)
#Call the function to prepare test data - n_features = 2
testX, testY = process_data(test, n_features)
print (testX.shape , testY.shape)
# Out:
# (1407, 2) (1407,)
# (351, 2) (351,)

# %%
#Call the function to prepare full  data - n_features = 2
stocksX, stocksY = process_data(stocks, n_features)
print (stocksX.shape , stocksY.shape)

#Display the First 10 Records from Train X
display (trainX[:10])

#Display the First 10 Records from TrainY
display (trainY[:10])

#Reshape to 3D array to use for LSTM /Deep Learning model
# reshaping trainX and testX to use in deep learning model
trainX = trainX.reshape(trainX.shape[0] , 1 ,trainX.shape[1])
display (trainX.shape)

#Reshape to 3D array test X
testX = testX.reshape(testX.shape[0] , 1 ,testX.shape[1])
display (testX.shape)

#Reshape to 3D array  full data set
stocksX= stocksX.reshape(stocksX.shape[0] , 1 ,stocksX.shape[1])
display (stocksX.shape)
# Out:
# (1760, 2) (1760,)
# array([[0.14559109, 0.14874031],
#        [0.14874031, 0.14728683],
#        [0.14728683, 0.13590119],
#        [0.13590119, 0.13590119],
#        [0.13590119, 0.13687016],
#        [0.13687016, 0.13541667],
#        [0.13541667, 0.14074613],
#        [0.14074613, 0.14607561],
#        [0.14607561, 0.13880814],
#        [0.13880814, 0.13711241]])
# array([0.14728683, 0.13590119, 0.13590119, 0.13687016, 0.13541667,
#        0.14074613, 0.14607561, 0.13880814, 0.13711241, 0.1281492 ])
# (1407, 1, 2)
# (351, 1, 2)
# (1760, 1, 2)

# %%
# !pip install tensorflow==2.20.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
# Create Check Points

# Checkpointing the model when required and using callbacks
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint

# Filepath to save the best model
filepath = "stock_weights1.keras"

# Reduce learning rate when validation loss stops improving
lr_reduce = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    min_delta=0.0001,
    patience=1,
    verbose=1
)

# Save the best model based on validation loss
checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    mode='max'
)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, LSTM

# Number of features (example: 2 features such as "Open" and "Close")
n_features = 2
timesteps = 1   # use 1 if you only look at one day at a time
# if you use sequences like last 60 days, set timesteps = 60

# Create the model – Fully connected Layer
model = Sequential()

# GRU Layer
model.add(GRU(256, input_shape=(timesteps, n_features), return_sequences=True))

# Dropout Layer
model.add(Dropout(0.4))

# LSTM Layer
model.add(LSTM(256))

# Dropout Layer
model.add(Dropout(0.4))

# Dense Layer
model.add(Dense(64, activation='relu'))

# Output Layer (1 neuron)
model.add(Dense(1))

# Print model summary
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 1, 256)         │       199,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 256)            │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 741,505 (2.83 MB)
#  Trainable params: 741,505 (2.83 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
import sys
print(sys.version)
# Out:
# 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.0.2

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# absolufy-imports                      0.3.1
# accelerate                            1.10.1
# aiofiles                              24.1.0
# aiohappyeyeballs                      2.6.1
# aiohttp                               3.12.15
# aiosignal                             1.4.0
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.11.2
# alembic                               1.16.5
# altair                                5.5.0
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.10.0
# anywidget                             0.9.18
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  25.1.0
# array_record                          0.8.1
# arrow                                 1.3.0
# arviz                                 0.22.0
# astropy                               7.1.0
# astropy-iers-data                     0.2025.9.15.0.37.0
# astunparse                            1.6.3
# atpublic                              5.1
# attrs                                 25.3.0
# audioread                             3.0.1
# Authlib                               1.6.4
# autograd                              1.8.0
# babel                                 2.17.0
# backcall                              0.2.0
# beartype                              0.21.0
# beautifulsoup4                        4.13.5
# betterproto                           2.0.0b6
# bigframes                             2.21.0
# bigquery-magics                       0.10.3
# bleach                                6.2.0
# blinker                               1.9.0
# blis                                  1.3.0
# blobfile                              3.1.0
# blosc2                                3.8.0
# bokeh                                 3.7.3
# Bottleneck                            1.4.2
# bqplot                                0.12.45
# branca                                0.8.1
# Brotli                                1.1.0
# build                                 1.3.0
# CacheControl                          0.14.3
# cachetools                            5.5.2
# catalogue                             2.0.10
# certifi                               2025.8.3
# cffi                                  2.0.0
# chardet                               5.2.0
# charset-normalizer                    3.4.3
# chex                                  0.1.90
# clarabel                              0.11.1
# click                                 8.2.1
# cloudpathlib                          0.22.0
# cloudpickle                           3.1.1
# cmake                                 3.31.6
# cmdstanpy                             1.2.5
# colorcet                              3.1.0
# colorlover                            0.3.0
# colour                                0.1.5
# community                             1.0.0b1
# confection                            0.1.5
# cons                                  0.4.7
# contourpy                             1.3.3
# cramjam                               2.11.0
# cryptography                          43.0.3
# cuda-python                           12.6.2.post1
# cudf-cu12                             25.6.0
# cudf-polars-cu12                      25.6.0
# cufflinks                             0.17.3
# cuml-cu12                             25.6.0
# cupy-cuda12x                          13.3.0
# curl_cffi                             0.13.0
# cuvs-cu12                             25.6.1
# cvxopt                                1.3.2
# cvxpy                                 1.6.7
# cycler                                0.12.1
# cyipopt                               1.5.0
# cymem                                 2.0.11
# Cython                                3.0.12
# dask                                  2025.5.0
# dask-cuda                             25.6.0
# dask-cudf-cu12                        25.6.0
# dataproc-spark-connect                0.8.3
# datasets                              4.0.0
# db-dtypes                             1.4.3
# dbus-python                           1.2.18
# debugpy                               1.8.15
# decorator                             4.4.2
# defusedxml                            0.7.1
# diffusers                             0.35.1
# dill                                  0.3.8
# distributed                           2025.5.0
# distributed-ucxx-cu12                 0.44.0
# distro                                1.9.0
# dlib                                  19.24.6
# dm-tree                               0.1.9
# docstring_parser                      0.17.0
# docutils                              0.21.2
# dopamine_rl                           4.1.2
# duckdb                                1.3.2
# earthengine-api                       1.5.24
# easydict                              1.13
# editdistance                          0.8.1
# eerepr                                0.1.2
# einops                                0.8.1
# en_core_web_sm                        3.8.0
# entrypoints                           0.4
# et_xmlfile                            2.0.0
# etils                                 1.13.0
# etuples                               0.3.10
# Farama-Notifications                  0.0.4
# fastai                                2.8.4
# fastapi                               0.116.2
# fastcore                              1.8.8
# fastdownload                          0.0.7
# fastjsonschema                        2.21.2
# fastprogress                          1.0.3
# fastrlock                             0.8.3
# fasttransform                         0.0.2
# ffmpy                                 0.6.1
# filelock                              3.19.1
# firebase-admin                        6.9.0
# Flask                                 3.1.2
# flatbuffers                           25.2.10
# flax                                  0.10.6
# folium                                0.20.0
# fonttools                             4.60.0
# fqdn                                  1.5.1
# frozendict                            2.4.6
# frozenlist                            1.7.0
# fsspec                                2025.3.0
# future                                1.0.0
# gast                                  0.6.0
# gcsfs                                 2025.3.0
# GDAL                                  3.8.4
# gdown                                 5.2.0
# geemap                                0.35.3
# geocoder                              1.38.1
# geographiclib                         2.1
# geopandas                             1.1.1
# geopy                                 2.4.1
# gin-config                            0.5.0
# gitdb                                 4.0.12
# GitPython                             3.1.45
# glob2                                 0.7
# google                                2.0.3
# google-adk                            1.14.1
# google-ai-generativelanguage          0.6.15
# google-api-core                       2.25.1
# google-api-python-client              2.182.0
# google-auth                           2.38.0
# google-auth-httplib2                  0.2.0
# google-auth-oauthlib                  1.2.2
# google-cloud-aiplatform               1.114.0
# google-cloud-appengine-logging        1.6.2
# google-cloud-audit-log                0.3.2
# google-cloud-bigquery                 3.38.0
# google-cloud-bigquery-connection      1.18.3
# google-cloud-bigquery-storage         2.33.1
# google-cloud-bigtable                 2.32.0
# google-cloud-core                     2.4.3
# google-cloud-dataproc                 5.21.0
# google-cloud-datastore                2.21.0
# google-cloud-firestore                2.21.0
# google-cloud-functions                1.20.4
# google-cloud-language                 2.17.2
# google-cloud-logging                  3.12.1
# google-cloud-resource-manager         1.14.2
# google-cloud-secret-manager           2.24.0
# google-cloud-spanner                  3.57.0
# google-cloud-speech                   2.33.0
# google-cloud-storage                  2.19.0
# google-cloud-trace                    1.16.2
# google-cloud-translate                3.21.1
# google-colab                          1.0.0
# google-crc32c                         1.7.1
# google-genai                          1.38.0
# google-generativeai                   0.8.5
# google-pasta                          0.2.0
# google-resumable-media                2.7.2
# googleapis-common-protos              1.70.0
# googledrivedownloader                 1.1.0
# gradio                                5.46.0
# gradio_client                         1.13.0
# graphviz                              0.21
# greenlet                              3.2.4
# groovy                                0.1.2
# grpc-google-iam-v1                    0.14.2
# grpc-interceptor                      0.15.4
# grpcio                                1.75.0
# grpcio-status                         1.71.2
# grpclib                               0.4.8
# gspread                               6.2.1
# gspread-dataframe                     4.0.0
# gym                                   0.25.2
# gym-notices                           0.1.0
# gymnasium                             1.2.0
# h11                                   0.16.0
# h2                                    4.3.0
# h5netcdf                              1.6.4
# h5py                                  3.14.0
# hdbscan                               0.8.40
# hf_transfer                           0.1.9
# hf-xet                                1.1.10
# highspy                               1.11.0
# holidays                              0.81
# holoviews                             1.21.0
# hpack                                 4.1.0
# html5lib                              1.1
# httpcore                              1.0.9
# httpimport                            1.4.1
# httplib2                              0.31.0
# httpx                                 0.28.1
# httpx-sse                             0.4.1
# huggingface-hub                       0.35.0
# humanize                              4.13.0
# hyperframe                            6.1.0
# hyperopt                              0.2.7
# ibis-framework                        9.5.0
# idna                                  3.10
# imageio                               2.37.0
# imageio-ffmpeg                        0.6.0
# imagesize                             1.4.1
# imbalanced-learn                      0.14.0
# immutabledict                         4.2.1
# importlib_metadata                    8.7.0
# importlib_resources                   6.5.2
# imutils                               0.5.4
# inflect                               7.5.0
# iniconfig                             2.1.0
# intel-cmplr-lib-ur                    2025.2.1
# intel-openmp                          2025.2.1
# ipyevents                             2.0.4
# ipyfilechooser                        0.6.0
# ipykernel                             6.17.1
# ipyleaflet                            0.20.0
# ipyparallel                           8.8.0
# ipython                               7.34.0
# ipython-genutils                      0.2.0
# ipython-sql                           0.5.0
# ipytree                               0.2.2
# ipywidgets                            7.7.1
# isoduration                           20.11.0
# itsdangerous                          2.2.0
# jaraco.classes                        3.4.0
# jaraco.context                        6.0.1
# jaraco.functools                      4.3.0
# jax                                   0.5.3
# jax-cuda12-pjrt                       0.5.3
# jax-cuda12-plugin                     0.5.3
# jaxlib                                0.5.3
# jeepney                               0.9.0
# jieba                                 0.42.1
# Jinja2                                3.1.6
# jiter                                 0.11.0
# joblib                                1.5.2
# jsonpatch                             1.33
# jsonpickle                            4.1.1
# jsonpointer                           3.0.0
# jsonschema                            4.25.1
# jsonschema-specifications             2025.9.1
# jupyter_client                        7.4.9
# jupyter-console                       6.6.3
# jupyter_core                          5.8.1
# jupyter-events                        0.12.0
# jupyter_kernel_gateway                2.5.2
# jupyter-leaflet                       0.20.0
# jupyter_server                        2.14.0
# jupyter_server_terminals              0.5.3
# jupyterlab_pygments                   0.3.0
# jupyterlab_widgets                    3.0.15
# jupytext                              1.17.3
# kaggle                                1.7.4.5
# kagglehub                             0.3.13
# keras                                 3.10.0
# keras-hub                             0.21.1
# keras-nlp                             0.21.1
# keyring                               25.6.0
# keyrings.google-artifactregistry-auth 1.1.2
# kiwisolver                            1.4.9
# langchain                             0.3.27
# langchain-core                        0.3.76
# langchain-text-splitters              0.3.11
# langcodes                             3.5.0
# langsmith                             0.4.28
# language_data                         1.3.0
# lark                                  1.2.2
# launchpadlib                          1.10.16
# lazr.restfulclient                    0.14.4
# lazr.uri                              1.0.6
# lazy_loader                           0.4
# libclang                              18.1.1
# libcudf-cu12                          25.6.0
# libcugraph-cu12                       25.6.0
# libcuml-cu12                          25.6.0
# libcuvs-cu12                          25.6.1
# libkvikio-cu12                        25.6.0
# libpysal                              4.13.0
# libraft-cu12                          25.6.0
# librmm-cu12                           25.6.0
# librosa                               0.11.0
# libucx-cu12                           1.18.1
# libucxx-cu12                          0.44.0
# lightgbm                              4.6.0
# linkify-it-py                         2.0.3
# llvmlite                              0.43.0
# locket                                1.0.0
# logical-unification                   0.4.6
# lxml                                  5.4.0
# Mako                                  1.3.10
# marisa-trie                           1.3.1
# Markdown                              3.9
# markdown-it-py                        4.0.0
# MarkupSafe                            3.0.2
# matplotlib                            3.10.0
# matplotlib-inline                     0.1.7
# matplotlib-venn                       1.1.2
# mcp                                   1.14.1
# mdit-py-plugins                       0.5.0
# mdurl                                 0.1.2
# miniKanren                            1.0.5
# missingno                             0.5.2
# mistune                               3.1.4
# mizani                                0.13.5
# mkl                                   2025.2.0
# ml_dtypes                             0.5.3
# mlxtend                               0.23.4
# more-itertools                        10.8.0
# moviepy                               1.0.3
# mpmath                                1.3.0
# msgpack                               1.1.1
# multidict                             6.6.4
# multipledispatch                      1.0.0
# multiprocess                          0.70.16
# multitasking                          0.0.12
# murmurhash                            1.0.13
# music21                               9.3.0
# namex                                 0.1.0
# narwhals                              2.5.0
# natsort                               8.4.0
# nbclassic                             1.3.3
# nbclient                              0.10.2
# nbconvert                             7.16.6
# nbformat                              5.10.4
# ndindex                               1.10.0
# nest-asyncio                          1.6.0
# networkx                              3.5
# nibabel                               5.3.2
# nltk                                  3.9.1
# notebook                              6.5.7
# notebook_shim                         0.2.4
# numba                                 0.60.0
# numba-cuda                            0.11.0
# numexpr                               2.12.1
# numpy                                 2.0.2
# nvidia-cublas-cu12                    12.6.4.1
# nvidia-cuda-cupti-cu12                12.6.80
# nvidia-cuda-nvcc-cu12                 12.5.82
# nvidia-cuda-nvrtc-cu12                12.6.77
# nvidia-cuda-runtime-cu12              12.6.77
# nvidia-cudnn-cu12                     9.10.2.21
# nvidia-cufft-cu12                     11.3.0.4
# nvidia-cufile-cu12                    1.11.1.6
# nvidia-curand-cu12                    10.3.7.77
# nvidia-cusolver-cu12                  11.7.1.2
# nvidia-cusparse-cu12                  12.5.4.2
# nvidia-cusparselt-cu12                0.7.1
# nvidia-ml-py                          12.575.51
# nvidia-nccl-cu12                      2.27.3
# nvidia-nvjitlink-cu12                 12.6.85
# nvidia-nvtx-cu12                      12.6.77
# nvtx                                  0.2.13
# nx-cugraph-cu12                       25.6.0
# oauth2client                          4.1.3
# oauthlib                              3.3.1
# omegaconf                             2.3.0
# openai                                1.108.0
# opencv-contrib-python                 4.12.0.88
# opencv-python                         4.12.0.88
# opencv-python-headless                4.12.0.88
# openpyxl                              3.1.5
# opentelemetry-api                     1.37.0
# opentelemetry-exporter-gcp-trace      1.9.0
# opentelemetry-resourcedetector-gcp    1.9.0a0
# opentelemetry-sdk                     1.37.0
# opentelemetry-semantic-conventions    0.58b0
# opt_einsum                            3.4.0
# optax                                 0.2.6
# optree                                0.17.0
# orbax-checkpoint                      0.11.24
# orjson                                3.11.3
# osqp                                  1.0.4
# overrides                             7.7.0
# packaging                             25.0
# pandas                                2.2.2
# pandas-datareader                     0.10.0
# pandas-gbq                            0.29.2
# pandas-stubs                          2.2.2.240909
# pandocfilters                         1.5.1
# panel                                 1.8.1
# param                                 2.2.1
# parso                                 0.8.5
# parsy                                 2.2
# partd                                 1.4.2
# patsy                                 1.0.1
# peewee                                3.18.2
# peft                                  0.17.1
# pexpect                               4.9.0
# pickleshare                           0.7.5
# pillow                                11.3.0
# pip                                   24.1.2
# platformdirs                          4.4.0
# plotly                                5.24.1
# plotnine                              0.14.5
# pluggy                                1.6.0
# plum-dispatch                         2.5.7
# ply                                   3.11
# polars                                1.25.2
# pooch                                 1.8.2
# portpicker                            1.5.2
# preshed                               3.0.10
# prettytable                           3.16.0
# proglog                               0.1.12
# progressbar2                          4.5.0
# prometheus_client                     0.22.1
# promise                               2.3
# prompt_toolkit                        3.0.52
# propcache                             0.3.2
# prophet                               1.1.7
# proto-plus                            1.26.1
# protobuf                              5.29.5
# psutil                                5.9.5
# psycopg2                              2.9.10
# psygnal                               0.14.1
# ptyprocess                            0.7.0
# py-cpuinfo                            9.0.0
# py4j                                  0.10.9.7
# pyarrow                               18.1.0
# pyasn1                                0.6.1
# pyasn1_modules                        0.4.2
# pycairo                               1.28.0
# pycocotools                           2.0.10
# pycparser                             2.23
# pycryptodomex                         3.23.0
# pydantic                              2.11.9
# pydantic_core                         2.33.2
# pydantic-settings                     2.10.1
# pydata-google-auth                    1.9.1
# pydot                                 3.0.4
# pydotplus                             2.0.2
# PyDrive2                              1.21.3
# pydub                                 0.25.1
# pyerfa                                2.0.1.5
# pygame                                2.6.1
# pygit2                                1.18.2
# Pygments                              2.19.2
# PyGObject                             3.42.0
# PyJWT                                 2.10.1
# pylibcudf-cu12                        25.6.0
# pylibcugraph-cu12                     25.6.0
# pylibraft-cu12                        25.6.0
# pymc                                  5.25.1
# pynndescent                           0.5.13
# pynvjitlink-cu12                      0.7.0
# pynvml                                12.0.0
# pyogrio                               0.11.1
# pyomo                                 6.9.4
# PyOpenGL                              3.1.10
# pyOpenSSL                             24.2.1
# pyparsing                             3.2.4
# pyperclip                             1.10.0
# pyproj                                3.7.2
# pyproject_hooks                       1.2.0
# pyshp                                 2.3.1
# PySocks                               1.7.1
# pyspark                               3.5.1
# pytensor                              2.31.7
# pytest                                8.4.2
# python-apt                            0.0.0
# python-box                            7.3.2
# python-dateutil                       2.9.0.post0
# python-dotenv                         1.1.1
# python-json-logger                    3.3.0
# python-louvain                        0.16
# python-multipart                      0.0.20
# python-slugify                        8.0.4
# python-snappy                         0.7.3
# python-utils                          3.9.1
# pytz                                  2025.2
# pyviz_comms                           3.0.6
# PyWavelets                            1.9.0
# PyYAML                                6.0.2
# pyzmq                                 26.2.1
# raft-dask-cu12                        25.6.0
# rapids-dask-dependency                25.6.0
# rapids-logger                         0.1.1
# ratelim                               0.1.6
# referencing                           0.36.2
# regex                                 2024.11.6
# requests                              2.32.4
# requests-oauthlib                     2.0.0
# requests-toolbelt                     1.0.0
# requirements-parser                   0.9.0
# rfc3339-validator                     0.1.4
# rfc3986-validator                     0.1.1
# rfc3987-syntax                        1.1.0
# rich                                  13.9.4
# rmm-cu12                              25.6.0
# roman-numerals-py                     3.1.0
# rpds-py                               0.27.1
# rpy2                                  3.5.17
# rsa                                   4.9.1
# ruff                                  0.13.0
# safehttpx                             0.1.6
# safetensors                           0.6.2
# scikit-image                          0.25.2
# scikit-learn                          1.6.1
# scipy                                 1.16.2
# scooby                                0.10.1
# scs                                   3.2.8
# seaborn                               0.13.2
# SecretStorage                         3.4.0
# semantic-version                      2.10.0
# Send2Trash                            1.8.3
# sentence-transformers                 5.1.0
# sentencepiece                         0.2.1
# sentry-sdk                            2.38.0
# setuptools                            75.2.0
# shap                                  0.48.0
# shapely                               2.1.1
# shellingham                           1.5.4
# simple-parsing                        0.1.7
# simplejson                            3.20.1
# simsimd                               6.5.3
# six                                   1.17.0
# sklearn-pandas                        2.2.0
# slicer                                0.0.8
# smart_open                            7.3.1
# smmap                                 5.0.2
# sniffio                               1.3.1
# snowballstemmer                       3.0.1
# sortedcontainers                      2.4.0
# soundfile                             0.13.1
# soupsieve                             2.8
# soxr                                  1.0.0
# spacy                                 3.8.7
# spacy-legacy                          3.0.12
# spacy-loggers                         1.0.5
# spanner-graph-notebook                1.1.8
# Sphinx                                8.2.3
# sphinxcontrib-applehelp               2.0.0
# sphinxcontrib-devhelp                 2.0.0
# sphinxcontrib-htmlhelp                2.1.0
# sphinxcontrib-jsmath                  1.0.1
# sphinxcontrib-qthelp                  2.0.0
# sphinxcontrib-serializinghtml         2.0.0
# SQLAlchemy                            2.0.43
# sqlalchemy-spanner                    1.16.0
# sqlglot                               25.20.2
# sqlparse                              0.5.3
# srsly                                 2.5.1
# sse-starlette                         3.0.2
# stanio                                0.5.1
# starlette                             0.48.0
# statsmodels                           0.14.5
# stringzilla                           4.0.11
# stumpy                                1.13.0
# sympy                                 1.13.3
# tables                                3.10.2
# tabulate                              0.9.0
# tbb                                   2022.2.0
# tblib                                 3.1.0
# tcmlib                                1.4.0
# tenacity                              8.5.0
# tensorboard                           2.19.0
# tensorboard-data-server               0.7.2
# tensorflow                            2.19.0
# tensorflow-datasets                   4.9.9
# tensorflow_decision_forests           1.12.0
# tensorflow-hub                        0.16.1
# tensorflow-metadata                   1.17.2
# tensorflow-probability                0.25.0
# tensorflow-text                       2.19.0
# tensorstore                           0.1.76
# termcolor                             3.1.0
# terminado                             0.18.1
# text-unidecode                        1.3
# textblob                              0.19.0
# tf_keras                              2.19.0
# tf-slim                               1.1.0
# thinc                                 8.3.6
# threadpoolctl                         3.6.0
# tifffile                              2025.9.9
# tiktoken                              0.11.0
# timm                                  1.0.19
# tinycss2                              1.4.0
# tokenizers                            0.22.0
# toml                                  0.10.2
# tomlkit                               0.13.3
# toolz                                 0.12.1
# torch                                 2.8.0+cu126
# torchao                               0.10.0
# torchaudio                            2.8.0+cu126
# torchdata                             0.11.0
# torchsummary                          1.5.1
# torchtune                             0.6.1
# torchvision                           0.23.0+cu126
# tornado                               6.4.2
# tqdm                                  4.67.1
# traitlets                             5.7.1
# traittypes                            0.2.1
# transformers                          4.56.1
# treelite                              4.4.1
# treescope                             0.1.10
# triton                                3.4.0
# tsfresh                               0.21.1
# tweepy                                4.16.0
# typeguard                             4.4.4
# typer                                 0.17.4
# types-python-dateutil                 2.9.0.20250822
# types-pytz                            2025.2.0.20250809
# types-setuptools                      80.9.0.20250822
# typing_extensions                     4.15.0
# typing-inspection                     0.4.1
# tzdata                                2025.2
# tzlocal                               5.3.1
# uc-micro-py                           1.0.3
# ucx-py-cu12                           0.44.0
# ucxx-cu12                             0.44.0
# umap-learn                            0.5.9.post2
# umf                                   0.11.0
# uri-template                          1.3.0
# uritemplate                           4.2.0
# urllib3                               2.5.0
# uvicorn                               0.35.0
# vega-datasets                         0.9.0
# wadllib                               1.3.6
# wandb                                 0.21.4
# wasabi                                1.1.3
# watchdog                              6.0.0
# wcwidth                               0.2.13
# weasel                                0.4.1
# webcolors                             24.11.1
# webencodings                          0.5.1
# websocket-client                      1.8.0
# websockets                            15.0.1
# Werkzeug                              3.1.3
# wheel                                 0.45.1
# widgetsnbextension                    3.6.10
# wordcloud                             1.9.4
# wrapt                                 1.17.3
# wurlitzer                             3.1.1
# xarray                                2025.9.0
# xarray-einstats                       0.9.1
# xgboost                               3.0.5
# xlrd                                  2.0.2
# xxhash                                3.5.0
# xyzservices                           2025.4.0
# yarl                                  1.20.1
# ydf                                   0.13.0
# yellowbrick                           1.5
# yfinance                              0.2.66
# zict                                  3.0.0
# zipp                                  3.23.0
# zstandard                             0.25.0

# %%
# !pip uninstall tensorflow keras tensorflow-intel -y
# !pip install tensorflow==2.13.0 keras==2.13.1

# %%
# !pip install scikit-learn

# %%
from h11 import Data
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from sklearn.preprocessing import MinMaxScaler

#Compile the Model
# Selecting the loss measurement metrics and optimizer for our model, to find out mean square error
model.compile(loss='mean_squared_error', optimizer=Adam( 0.0005) , metrics = ['mean_squared_error'])

#Fit the Model
# fitting the data i.e training the trainX, to relate to trainY
# epochs is the times each data in send to fit
# batch size is the size of information send at a time
# validation_data is the validation or data used for testing
history = model.fit(trainX, trainY, epochs=100 , batch_size = 128 ,
          callbacks = [checkpoint , lr_reduce] , validation_data = (testX,testY))


#Predict the value for testX, display top 10 records

test_pred = model.predict(testX)
display (test_pred [:10])

#Inverse Transform the data – Convert the data to Original form
test_pred = scaler.inverse_transform(test_pred)
display (test_pred [:10])

#Reshape and Display Original Data
testY = testY.reshape(testY.shape[0] , 1)
#Converting reshaped list in 1D array so that it will be efficient in plotting
testY = scaler.inverse_transform(testY)
# taking testY from 1 to 10
display (testY[:10])
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1627 - mean_squared_error: 0.1627
# Epoch 1: val_loss improved from -inf to 0.18147, saving model to stock_weights1.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 11s 97ms/step - loss: 0.1616 - mean_squared_error: 0.1616 - val_loss: 0.1815 - val_mean_squared_error: 0.1815 - learning_rate: 5.0000e-04
# Epoch 2/100
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0690 - mean_squared_error: 0.0690
# Epoch 2: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0635 - mean_squared_error: 0.0635 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - learning_rate: 5.0000e-04
# Epoch 3/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0223 - mean_squared_error: 0.0223
# Epoch 3: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - learning_rate: 5.0000e-04
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0103 - mean_squared_error: 0.0103
# Epoch 4: val_loss did not improve from 0.18147
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0086 - val_mean_squared_error: 0.0086 - learning_rate: 5.0000e-04
# Epoch 5/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0067 - mean_squared_error: 0.0067
# Epoch 5: val_loss did not improve from 0.18147
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - learning_rate: 5.0000e-05
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 6: val_loss did not improve from 0.18147
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - learning_rate: 5.0000e-06
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 7: val_loss did not improve from 0.18147
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-07
# Epoch 8/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 8: val_loss did not improve from 0.18147
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-08
# Epoch 9/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 9: val_loss did not improve from 0.18147
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-09
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 10: val_loss did not improve from 0.18147
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-10
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 11: val_loss did not improve from 0.18147
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-12.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-11
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 12: val_loss did not improve from 0.18147
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-13.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-12
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 13: val_loss did not improve from 0.18147
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 5.0000005221220725e-14.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-13
# Epoch 14/100
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 14: val_loss did not improve from 0.18147
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.000000589884709e-15.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-14
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 15: val_loss did not improve from 0.18147
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 5.000000759291298e-16.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-15
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 16: val_loss did not improve from 0.18147
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 5.000000547533061e-17.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-16
# Epoch 17/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 17: val_loss did not improve from 0.18147
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 5.000000415184163e-18.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-17
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 18: val_loss did not improve from 0.18147
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 5.000000332466102e-19.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-18
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 19: val_loss did not improve from 0.18147
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 5.000000229068525e-20.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-19
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 20: val_loss did not improve from 0.18147
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 5.00000016444504e-21.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-20
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 21: val_loss did not improve from 0.18147
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 5.000000245224397e-22.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-21
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 22: val_loss did not improve from 0.18147
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 5.0000003461985925e-23.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-22
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 23: val_loss did not improve from 0.18147
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 5.000000472416337e-24.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-23
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 24: val_loss did not improve from 0.18147
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 5.000000393530247e-25.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-24
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 25: val_loss did not improve from 0.18147
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5.000000590745473e-26.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-25
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 26: val_loss did not improve from 0.18147
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 5.000000714004989e-27.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-26
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 27: val_loss did not improve from 0.18147
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 5.00000071400499e-28.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-27
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 28: val_loss did not improve from 0.18147
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 5.000000617708492e-29.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-28
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 29: val_loss did not improve from 0.18147
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.0000006177084924e-30.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-29
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 30: val_loss did not improve from 0.18147
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 5.0000007681717695e-31.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-30
# Epoch 31/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 31: val_loss did not improve from 0.18147
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 5.000000956250865e-32.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-31
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 32: val_loss did not improve from 0.18147
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 5.0000010738003005e-33.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-32
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 33: val_loss did not improve from 0.18147
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 5.000001220737094e-34.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-33
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 34: val_loss did not improve from 0.18147
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 5.000001037066102e-35.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-34
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 35: val_loss did not improve from 0.18147
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-36.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-35
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 36: val_loss did not improve from 0.18147
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-37.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-36
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 37: val_loss did not improve from 0.18147
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 5.000000628111158e-38.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-37
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 38: val_loss did not improve from 0.18147
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 5.000000516007281e-39.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-38
# Epoch 39/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 39: val_loss did not improve from 0.18147
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 5.000001076526666e-40.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-39
# Epoch 40/100
#  9/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0051 - mean_squared_error: 0.0051
# Epoch 40: val_loss did not improve from 0.18147
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 5.000001076526667e-41.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-40
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 41: val_loss did not improve from 0.18147
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.99997305055738e-42.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0000e-41
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 42: val_loss did not improve from 0.18147
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.9998329207109475e-43.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 4.9998e-42
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 43: val_loss did not improve from 0.18147
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 5.002635517639597e-44.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0026e-43
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 44: val_loss did not improve from 0.18147
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.0446744715693416e-45.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.0447e-44
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 45: val_loss did not improve from 0.18147
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 5.6051938572992686e-46.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 5.6052e-45
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 46: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 47: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 48: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 49: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 50: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 51: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 52: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 53: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0061 - mean_squared_error: 0.0061
# Epoch 54: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 55/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0063 - mean_squared_error: 0.0063
# Epoch 55: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 56: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 57: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 58: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 59: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 60: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 61: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 62: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 63: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 64: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 65: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 66: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 67: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 68: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 69: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 70: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 71: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 72: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 73: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 74: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 75: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 76: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 77: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 78/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 78: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 79: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 80/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 80: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 81/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 81: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0062 - mean_squared_error: 0.0062
# Epoch 82: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 83: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 84: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0055 - mean_squared_error: 0.0055
# Epoch 85: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 86: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 87: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 88: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0052 - mean_squared_error: 0.0052
# Epoch 89: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 90: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0060 - mean_squared_error: 0.0060
# Epoch 91: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 92: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 93/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 93: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 94: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0058 - mean_squared_error: 0.0058
# Epoch 95: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0057 - mean_squared_error: 0.0057
# Epoch 96: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0054 - mean_squared_error: 0.0054
# Epoch 97: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0059 - mean_squared_error: 0.0059
# Epoch 98: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 99/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0053 - mean_squared_error: 0.0053
# Epoch 99: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# Epoch 100/100
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0056 - mean_squared_error: 0.0056
# Epoch 100: val_loss did not improve from 0.18147
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - learning_rate: 0.0000e+00
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# array([[0.54459345],
#        [0.5194058 ],
#        [0.5189807 ],
#        [0.5352918 ],
#        [0.5368202 ],
#        [0.5315784 ],
#        [0.52297866],
#        [0.5079105 ],
#        [0.4866969 ],
#        [0.46056587]], dtype=float32)
# array([[33.570816],
#        [32.53107 ],
#        [32.513523],
#        [33.186844],
#        [33.249935],
#        [33.033558],
#        [32.67856 ],
#        [32.056545],
#        [31.180847],
#        [30.102158]], dtype=float32)
# array([[34.490002],
#        [35.93    ],
#        [36.240002],
#        [36.099998],
#        [35.689999],
#        [35.189999],
#        [34.099998],
#        [32.93    ],
#        [31.309999],
#        [31.74    ]])

# %%
#Display the accuracy
from sklearn.metrics import r2_score
print (r2_score(testY,test_pred))

#Plot the Graph Actual and Predicted Data
# Ploting the graph of stock prices with time
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
# testY is the blue line
plt.plot(testY , 'b')
# pred is the red line
plt.plot(test_pred , 'r')
# Setting x axis as time
plt.xlabel('Time')
# Setting y axis as stock prices
plt.ylabel('Stock Prices')
# setting title
plt.title('Check the accuracy of the model with time')
# enabling grids in graph
plt.grid(True)
# it call the graph with labels, titles, lines
plt.show()
# Out:
# 0.4860248804711018
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %%
#Prediction Training Data and Check Accuracy
train_pred = model.predict(trainX)
train_pred = scaler.inverse_transform(train_pred)
trainY = trainY.reshape(trainY.shape[0] , 1)
trainY = scaler.inverse_transform(trainY)
print ('Display Accuracy Training Data')
display (r2_score(trainY,train_pred))
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Display Accuracy Training Data
# 0.9398237575503312

# %%
#Plot the Graph

# Ploting the graph of stock prices with time - Training Data
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(trainY  , 'b')
plt.plot(train_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices

# %%
#Prediction Full Data

stocks_pred = model.predict(stocksX)
stocks_pred = scaler.inverse_transform(stocks_pred)
stocksY = stocksY.reshape(stocksY.shape[0] , 1)
stocksY = scaler.inverse_transform(stocksY)
print ('Display Accuracy Training Data')
display (r2_score(stocksY,stocks_pred))
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Display Accuracy Training Data
# 0.935645303727702

# %%
#Plot the Graph
plt.rcParams["figure.figsize"] = (15,7)
plt.plot(stocksY  , 'b')
plt.plot(stocks_pred, 'r')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.title('Check the accuracy of the model with time')
plt.grid(True)
plt.show()

# %%
# Extract the data related to company - YHOO
results= df[df.symbol.isin (['YHOO'])]
# Update the data frame starting with 2nd records , since first prediction is for 2nd record
results= results [2:]
# Reset the index 0, 1,2 etc
results = results.reset_index(drop=True)
# Convert Predicted Value to Data Frame
df_stocks_pred= pd.DataFrame(stocks_pred, columns = ['Close_Prediction'])
# Concat Original and prediction data
results= pd.concat([results,df_stocks_pred],axis =1)
results.to_csv('results.csv')
display(results)
# Out:
#             date symbol       open      close        low       high  \
# 0     2010-01-06   YHOO  17.170000  17.170000  17.070000  17.299999
# 1     2010-01-07   YHOO  16.809999  16.700001  16.570000  16.900000
# 2     2010-01-08   YHOO  16.680000  16.700001  16.620001  16.760000
# 3     2010-01-11   YHOO  16.770000  16.740000  16.480000  16.830000
# 4     2010-01-12   YHOO  16.650000  16.680000  16.600000  16.860001
# ...          ...    ...        ...        ...        ...        ...
# 1755  2016-12-23   YHOO  38.459999  38.660000  38.369999  38.810001
# 1756  2016-12-27   YHOO  38.590000  38.919998  38.500000  39.070000
# 1757  2016-12-28   YHOO  39.119999  38.730000  38.709999  39.220001
# 1758  2016-12-29   YHOO  38.759998  38.639999  38.480000  38.930000
# 1759  2016-12-30   YHOO  38.720001  38.669998  38.430000  39.000000
#
#           volume  Close_Prediction
# 0     16422000.0         18.941540
# 1     31816300.0         18.965521
# 2     15470000.0         18.770737
# 3     16181900.0         18.604191
# 4     15672400.0         18.618935
# ...          ...               ...
# 1755   3840100.0         35.327099
# 1756   4240300.0         35.140076
# 1757   4393500.0         35.306042
# 1758   4170200.0         35.330383
# 1759   6431600.0         35.220901
#
# [1760 rows x 8 columns]
